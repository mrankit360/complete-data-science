# %%
## NLP using NLTK

# %%
corpus = """Hello Welcome,to Ankit NLP Tutorials.
Please do watch the entire course! to become expert in NLP."""

# %%
print(corpus)
# Out:
# Hello Welcome,to Ankit NLP Tutorials.
# Please do watch the entire course! to become expert in NLP.

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\91620\onedrive\desktop\data_science_pra\venv\lib\site-packages (3.9.4)
# Requirement already satisfied: click in c:\users\91620\onedrive\desktop\data_science_pra\venv\lib\site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in c:\users\91620\onedrive\desktop\data_science_pra\venv\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\91620\onedrive\desktop\data_science_pra\venv\lib\site-packages (from nltk) (2026.3.32)
# Requirement already satisfied: tqdm in c:\users\91620\onedrive\desktop\data_science_pra\venv\lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\users\91620\onedrive\desktop\data_science_pra\venv\lib\site-packages (from click->nltk) (0.4.6)

# %%
## Tokenization
## Sentence-->paragraphs

from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\91620\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome,to Ankit NLP Tutorials.
# Please do watch the entire course!
# to become expert in NLP.

# %%
## Paragraph-->words
## sentence-->words

from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Ankit',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Ankit',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()

tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Ankit',
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
