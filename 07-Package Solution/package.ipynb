# %% [markdown]
# ## Modules and Packages

# %%
import math

print(math.sqrt(25))
print(math.sin(90))
# Out:
# 5.0
# 0.8939966636005579

# %%
import datetime as dt
print(dt.datetime.now())
# Out:
# 2025-09-08 16:08:07.294226

# %%
import random

print(random.randint(1,100))
# Out:
# 2

# %%
import os

os.mkdir('new_directry')

print(os.listdir('.'))
os.rmdir('new_directry')
print(os.listdir('.'))
# Out:
# ['new_directry', 'package.ipynb']
# ['package.ipynb']

# %%
## sys mmoodule to prinnt python version currently in use and command line argument passed to the script
import sys

print(f"Python version: {sys.version}")
print(f"Command-line arguments: {sys.argv}")
# Out:
# Python version: 3.12.0 | packaged by Anaconda, Inc. | (main, Oct  2 2023, 17:20:38) [MSC v.1916 64 bit (AMD64)]
# Command-line arguments: ['c:\\Users\\91620\\OneDrive\\Desktop\\Data_science_pra\\venv\\Lib\\site-packages\\ipykernel_launcher.py', '--f=c:\\Users\\91620\\AppData\\Roaming\\jupyter\\runtime\\kernel-v39c8f28aaafdd45267d420310d3331c36fc612ad3.json']

# %%
import datetime

# Current date
today = datetime.date.today()
print(f"Today's date: {today}")

# Date 100 days from today
future_date = today + datetime.timedelta(days=100)
print(f"Date 100 days from today: {future_date}")

# Day of the week for a given date
given_date = datetime.date(2022, 1, 1)
print(f"Day of the week for 2022-01-01: {given_date.strftime('%A')}")
# Out:
# Today's date: 2025-09-08
# Date 100 days from today: 2025-12-17
# Day of the week for 2022-01-01: Saturday

# %%
from Mypackage import mymodule1, mymodule2

print(mymodule1.add(2,5))
print(mymodule2.multiply(1,5))
# Out:
# 7
# 5

# %%
from Mypackage import sub, multiply, add

print(sub(5,2))
# Out:
# 3

# %%
try:
    from Mypackage import non_existent_function
except ImportError as e:
    print(f"Error importing function: {e}")
# Out:
# Error importing function: cannot import name 'non_existent_function' from 'Mypackage' (c:\Users\91620\OneDrive\Desktop\Data_science_pra\7-Package Solution\Mypackage\__init__.py)
