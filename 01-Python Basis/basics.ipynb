# %%
2+1
# Out:
# 3

# %%
#swap number

a = 10
b = 5
##before swaping
print(f"before swap a: {a} and b: {b}")

a,b = b,a
print(f"after swap a:{a} and b:{b}")
# Out:
# before swap a: 10 and b: 5
# after swap a:5 and b:10

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(input("Enter a number: "))
# Out:
# 4

# %%
num = int(input("enter a num:"))
if (num > 0):
    print("positive")
elif (num < 0):
    print("negative")
else:
    print("Zero")
# Out:
# positive

# %%
a = 5
b = 10

print(f"before swap a:{a} and b:{b}")
a, b = b, a
print(f"after swap a:{a} and b:{b}")
# Out:
# before swap a:5 and b:10
# after swap a:10 and b:5

# %%
num = int(input("enter num"))
square = num*num
print(f"square of {num} is {square}")
# Out:
# square of 5 is 25

# %%
## sum of natural no
n = int(input("enter num"))
sum = (n * (n+1))/2
print(f"sum of {n} natural number is {sum}")
# Out:
# sum of 10 natural number is 55.0

# %%
year = int(input("enter year"))
if(year % 4 == 0 and year % 100 != 0) or (year%400 == 0):
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap yaer")
# Out:
# 1700 is not a leap yaer

# %%
str = input("string")
reversed_str = str[::-1]
print(reversed_str)
# Out:
# tikna

# %%
n = int(input("Enter a number: "))
sum = (n*(n+1))//2
print(f"sum of batural number: {sum}")
# Out:
# sum of batural number: 55

# %%
year = int(input("Enter the year"))

if year%4 == 0:
    if year%100 == 0:
        if year%400 == 0:
            print(f"{year} is leap")
        else:
            print(f"{year} is not leap")
    else:
        print(f"{year} is leap")
else:
    print(f"{year} is not leap")
# Out:
# 1900 is not leap

# %%
year = int(input("Enter the year"))

if (year%4==0 and year%100!=0) or (year%400):
    print(f"{year} is leap")
else:
    print(f"{year} is not leap")
# Out:
# 2024 is leap
